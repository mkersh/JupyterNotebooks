# %% [markdown]
# # Python Tests Notebook

# %%
import sys
import matplotlib.pyplot as plt
print(sys.version)
# Out:
# 3.7.1 (default, Dec 14 2018, 13:28:58)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
x = (1,2,3,4,5,6)

# %%
y = (i*i for i in x)

# %%
z = [i for i in range(100)]

# %%
zz = [i*i*i for i in z]

# %%
plt.plot(zz)

# %%
a1 = {"f1": 1,"f2": 2, 'f3': 0.5, 'f4': 10.5}

# %%
a1
# Out:
# {'f1': 1, 'f2': 2}

# %%
for k,v in a1.items():
    print("key = {0} value = {1}".format(k,v))
# Out:
# key = f1 value = 1
# key = f2 value = 2

# %%
plt.plot(a1.keys(),a1.values())
